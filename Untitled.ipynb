# %%
# ## 1. Calculate Area of a Circle

# #### Write a Python program which accepts the radius of a circle from the user and compute the area.
# ###### Program Console Sample Output 1:
# ###### Input Radius: 0.5
# ###### Area of Circle with radius 0.5 is 0.7853981634
x = float(input("Enter radius"))
y = x*x*3.142
print(y)

# ## 2. Check Number either positive, negative or zero

# #### Write a Python program to check if a number is positive, negative or zero
# ###### Program Console Sample Output 1:
# ###### Enter Number: -1
# ##### Negative Number Entered
# ###### Program Console Sample Output 2: 2
# ##### Integer: 3
# ##### Positive Number Entered
# ###### Program Console Sample Output 3:
# ##### Integer: 0
# ###### Zero Entered
number = int(input("Enter number to check:"))
if number >0 :
       print("Number is positive")
elif number < 0:
       print("Number is negative")
else:
       print("number is zero")


# ## 3. Divisibility Check of two numbers

# #### Write a Python program to check whether a number is completely divisible by another number. Accept two integer values form the user
# ##### Program Console Sample Output 1:
# ###### Enter numerator: 4
# ###### Enter Denominator: 2
# ##### Number 4 is Completely divisible by 2
# ###### Program Console Sample Output 2:
# ##### Enter numerator: 7
# 
# ##### Enter Denominator: 4
# ###### Number 7 is not Completely divisible by 4
number = int(input("Enter number"))
number2 = int(input("enter number"))
Ans = number%number2
if Ans==0:
    print("Number " +str(number) +" is divisible " +str(number2))
else:
    print("Number " +str(number) +" is not divisible " +str(number2))



# ## 4. Calculate Volume of a sphere

# ##### Write a Python program to get the volume of a sphere, please take the radius as input from user

# ##### Program Console Output:
# ##### Enter Radius of Sphere: 1
# ###### Volume of the Sphere with Radius 1 is 4.18

radius=float(input("Enter the radius of the sphere: "))
volume=1.33*3.142*radius**3
print(f"volume of sphere with radius {radius} is {volume}")

# ## 5. Copy string n times
# #### Write a Python program to get a string which is n (non-negative integer) copies of a given string.
# ##### Program Console Output:
# ##### Enter String: Hi
# ###### How many copies of String you need: 4
# ###### 4 Copies of Hi are HiHiHiHi
string=input("Enter a string: ")
string.split(" ")
n=int(input("How many of copies of string you want?: "))
if n>0:
    print(n,"copies of string {string} are: ", (string*n))
else:
    print("Invalid")

# ## 6. Check if number is Even or Odd
# ### Write a Python program to find whether a given number (accept from the user) is even or odd, print out an appropriate message to the user
# #### Program Console Output 1:
# ##### Enter Number: 4
# ###### 4 is Even
# #### Program Console Output 2:
# ##### Enter Number: 9
# ###### 9 is Odd
num=int(input("Enter number:"))
ans=num%2
if ans==0:
    print(str(num) + " is Even number")
else:
    print(str(num) + " is Odd number" )














# ## 7. Vowel Tester
# ### Write a Python program to test whether a passed letter is a vowel or not
# #### Program Console Output 1:
# ##### Enter a character: A
# ###### Letter A is Vowel
# #### Program Console Output 2:
# ##### Enter a character: e
# ###### Letter e is Vowel
# #### Program Console Output 2:
# ##### Enter a character: N
# ###### Letter N is not Vowel

vowels=['a','e','i','o','u']
letter=input("Enter a sound: ")
if letter in vowels :
    print(f"{letter} is vowel")
else:
    print(f"{letter} is not a vowel")
vow = input("enter alphabet to check: ")
if vow =='a'or vow =='e'or vow =='i'or vow=='o'or vow=='u':
    print("Alphabet {0} is vowel".format(vow))
elif vow=='A'or vow =='E'or vow =='I'or vow =='O' or vow =='U':
    print("Alphabet {0} is vowel".format(vow))
else:
print("Alphabet {0} is not vowel".format(vow))
vow = input("enter alphabet to check: ").lower()
if vow =='a'or vow =='e'or vow =='i'or vow=='o'or vow=='u':
    print("Alphabet {0} is vowel".format(vow))
else:
    print("Alphabet {0} is not vowel".format(vow))
# ## 8. Triangle area
# ### Write a Python program that will accept the base and height of a triangle and compute the area
# ###### Reference:
base=float(input("Enter the base"))
height=float(input("Enter the height"))
area=1/2*base*height
print("Area of triangle is: "+str(area))

# ## 9. Calculate Interest
# ### Write a Python program to compute the future value of a specified principal amount, rate of interest, and a number of years
# #### Program Console Sample 1:
# ##### Please enter principal amount: 10000
# ###### Please Enter Rate of interest in %: 0.1
# ###### Enter number of years for investment: 5
# ###### After 5 years your principal amount 10000 over an interest rate of 0.1 % will be 16105.1
amount = int(input("enter principal amount :  "))
intrest = float(input("enter Rate of interest:  "))
years = int(input("enter yrears : "))
result = amount*(1 + 10/100)**years
print('value will be {0}'.format(result))






# ## 10. Euclidean distance
# ### write a Python program to compute the distance between the points (x1, y1) and (x2, y2).
# #### Program Console Sample 1:
# ###### Enter Co-ordinate for x1: 2
# ###### Enter Co-ordinate for x2: 4
# ###### Enter Co-ordinate for y1: 4
# ###### Enter Co-ordinate for y2: 4
# ###### Distance between points (2, 4) and (4, 4) is 2
import math
x1=(int(input("Enter co-ordinate for x1:")))
x2=(int(input("Enter co-ordinate for x2")))
y1=(int(input("Enter co-ordinate for y1")))
y2=(int(input("Enter co-ordinate for y2:")))
x=x1-x2
y=y1-y2
z=(x*x)+(y*y)
ans=math.sqrt(z)
print('Distance between points ({0},{1}) and ({2},{3}) is {4}'.format(x1,x2,y1,y2,ans))
  x1=int(input("Enter Co-ordinate for x1: "))
x2=int(input("Enter Co-ordinate for x2: "))
y1=int(input("Enter Co-ordinate for y1: "))
y2=int(input("Enter Co-ordinate for y2: "))
import math
print("({0},{1})".format({x1},{y1}))
print("({0},{1})".format({x2},{y2}))
distance_formula = math.sqrt(pow(x2-x1,2) + pow(y2-y1,2))
distance_formula = round(distance_formula,2)
print("The Distance Between Points :"+str(distance_formula))



# ## 11. Feet to Centimeter Converter
# ### Write a Python program to convert height in feet to centimetres.
# ##### Program Console Sample 1:
# ###### Enter Height in Feet: 5
# ###### There are 152.4 Cm in 5 ft
# ###### Reference:
h=int(input("Enter height in feet:"))
height=h*12*2.54
print('there are {0} cm in {1}ft'.format(height,h))

feet=int(input("Enter height in feet"))
cm=feet*30.48
print("There are {0} cm in {1} ft ".format(cm,feet))













# ## 12. BMI Calculator
# ### Write a Python program to calculate body mass index
# ##### Program Console Sample 1:
# ###### Enter Height in Cm: 180
# ###### Enter Weight in Kg: 75
# ###### Your BMI is 23.15
Height=int(input("Enter Height in cm:"))
h=Height/100
weight=int(input("Enter weight in kg"))
H=h*h
BMI= weight/H
print('Your BMI is {0}'.format(BMI))

import math
height=int(input("Enter height in cm:"))
weight=int(input("Enter weight in kg:"))
BMI=(weight/(math.pow(height*0.012,2)))
BMI= round(BMI,2)
print("Your bmi is:{0}".format(BMI))



# ## 13. Sum of n Positive Integers
# ### Write a python program to sum of the first n positive integers
# #### Program Console Sample 1:
# ###### Enter value of n: 5
# ###### Sum of n Positive integers till 5 is 15
no=int(input("Enter value of n : "))
a=0
for b in range(0,no+1,1):
    a=a+b
print('sum of n positive integer till {0} is {1}'.format(no,a))

num=0
value=int(input("Enter the value of n: "))
for i in range(value+1):
    num+=i
    print("sum of n positive integers till {0} is {1}".format(value,num))




















# ## 14. Digits Sum of a Number
# ### Write a Python program to calculate the sum of the digits in an integer
# #### Program Console Sample 1:
# ##### Enter a number: 15
# ###### Sum of 1 + 5 is 6
# #### Program Console Sample 2:
# ##### Enter a number: 1234
# ###### Sum of 1 + 2 + 3 + 4 is 10

n=input("Enter any num ")
sum=0
for s in n:
    sum+=int(s)
print("The sum of num is:",sum)
